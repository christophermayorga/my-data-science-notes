# %%
import pandas as pd

# %% [markdown]
# 25 gorgeous swimming holes and pools within driving distance of San Antonio

# %%
df = pd.read_csv('swimming_holes_near_sa  - Sheet1.csv')

# %%
df
# Out:
#                       water_spot  size_in_acres           location  \
# 0              San Pedro Springs           46.0    San Antonio, TX
# 1              Garner State Park            NaN         Concan, TX
# 2   Lake Amistad Recreation Area            NaN        Del Rio, TX
# 3                    Comal River            NaN  New Braunfels, TX
# 4                    Canyon Lake            NaN    Canyon Lake, TX
# 5                 Krause Springs            NaN      Spicewood, TX
# 6              Blanco State Park            NaN         Blanco, TX
# 7                 Rio Vista Park            NaN     San Marcos, TX
# 8                    Medina Lake            NaN                NaN
# 9     Landa Park Aquatic Complex            NaN                NaN
# 10                     Deep Eddy            NaN         Austin, TX
# 11              San Marcos River            NaN     San Marcos, TX
# 12                 Woodlawn Pool            NaN    San Antonio, TX
# 13                     Blue Hole            NaN       Wimberly, TX
# 14          Guadalupe State Park            NaN  Spring Branch, TX
# 15               Paradise Canyon            NaN                NaN
# 16            Riding River Ranch            NaN                NaN
# 17                Barton Springs            NaN         Austin, TX
# 18      Chalk Bluff River Resort            NaN                NaN
# 19                  Jacob's Well            NaN      Wimberley, TX
# 20             Devil's Waterhole            NaN                NaN
# 21           Schumacher Crossing            NaN                NaN
# 22          The Slab Llano River            NaN          Kingsland
# 23              Utopia City Park            NaN         Utopia, TX
# 24            San Felipe Springs            NaN        Del Rio, TX
#
#     distance_from_me free  cost
# 0                NaN  NaN   NaN
# 1                NaN  NaN   NaN
# 2                NaN  NaN   NaN
# 3                NaN  NaN   NaN
# 4                NaN  NaN   NaN
# 5                NaN  NaN   NaN
# 6                NaN  NaN   NaN
# 7                NaN  Yes   0.0
# 8                NaN  NaN   NaN
# 9                NaN  NaN   NaN
# 10               NaN  NaN   NaN
# 11               NaN  NaN   NaN
# 12               NaN  NaN   NaN
# 13               NaN  NaN   NaN
# 14               NaN  NaN   NaN
# 15               NaN  NaN   NaN
# 16               NaN  NaN   NaN
# 17               NaN  NaN   NaN
# 18               NaN  NaN   NaN
# 19               NaN  NaN   NaN
# 20               NaN  NaN   NaN
# 21               NaN  NaN   NaN
# 22               NaN  NaN   NaN
# 23               NaN  NaN   NaN
# 24               NaN  NaN   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   water_spot        25 non-null     object
#  1   size_in_acres     1 non-null      float64
#  2   location          18 non-null     object
#  3   distance_from_me  0 non-null      float64
#  4   free              1 non-null      object
#  5   cost              1 non-null      float64
# dtypes: float64(3), object(3)
# memory usage: 1.3+ KB
